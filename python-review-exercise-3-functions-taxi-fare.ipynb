# %% [markdown]
# <a href="https://www.kaggle.com/code/cemprondanziel/python-review-exercise-3-functions-taxi-fare?scriptVersionId=124504769" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Python Review Exercise 3: Functions (Taxi Fare)
#
# ## Author: Danziel Cempron
#
# ## Description:
# ![Exercise Description](https://scontent.fmnl17-1.fna.fbcdn.net/v/t1.15752-9/339491068_1986069845071488_6283431975766141576_n.png?_nc_cat=100&ccb=1-7&_nc_sid=ae9488&_nc_ohc=CtrnLC9Dm80AX94XJpl&_nc_ht=scontent.fmnl17-1.fna&oh=03_AdTso7742M_Xd0y_Goj39n_02gktOzkFk9P-2cnGyraKTw&oe=6452FA9D)
#
# ## Date of Submission: April 4, 2023 11:30AM

# %% [markdown]
# ## OBJECTIVES:
# 1. Taxi Fare:
#     - Base = 40
#     - Per Minute = 2
#     - Per Kilometer = 13.50
# 2. Function that:
#     - Takes distance Traveled (km) and;
#     - Takes Travel Time (mins)
#     - return Total Fare
# 3. Main demonstrates function

# %% [markdown]
# # Create a function called 'get_fare' that calculates the fare with given parameters

# %%
# This code block is a function that 
# calculates the fare with two (2) given parameters
def get_fare(distance_traveled, 
             travel_time):
    
    # store constants in a variable
    base_fare = 40.0
    per_kilometer = 13.50
    per_minute = 2.0
    
    # calculates the distance traveled and travel time by multiplying to constants
    distance_traveled = distance_traveled * per_kilometer
    travel_time = travel_time * per_minute
    
    # calculates the total fare by adding values together
    total_fare = base_fare + distance_traveled + travel_time
    
    # returns variable total_fare
    return total_fare

# %% [markdown]
# # Create a function called 'main' that demonstrates the function 'get_fare'

# %%
# This code block is a function that 
# demonstrates the function 'get_fare'
def main():
    
    # asks the user for input
    distance = int(input("Please Enter the Distance Traveled (km): "))
    time = int(input("Please Enter the Travel Time (mins): "))

    # calculates the total_fare using the get_fare function
    # by passing 2 parameters distance and time
    total_fare = int(get_fare(distance, time))
    
    # prints the calculated total_fare
    print(f"Total fare is: {total_fare}")

# %% [markdown]
# # Running and Debugging the Program

# %%
# This code block
# runs the code for debugging
main()
# Out:
# Please Enter the Distance Traveled (km):  20
# Please Enter the Travel Time (mins):  30
# Total fare is: 370
